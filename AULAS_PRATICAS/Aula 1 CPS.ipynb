# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
from IPython.display import Audio, display

# %%
rate, data = wavfile.read('/Users/roman/Library/CloudStorage/OneDrive-InstitutoSuperiordeEngenhariadeLisboa/LEIM/3 Semestre/CPS/Python/Aula1.wav')

# %%
print(rate)
# Out:
# 44100

# %%
audio = data[:,0]
len(audio)
# Out:
# 222208

# %%
Audio(data=audio, rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
A1 = 1
A2 = 0.5
f1 = 15000
f2 = 8000
fs = 44100
t  = np.arange(0,222208/44100,1/fs)
N = 5*fs


x1 = A1*np.cos(2*np.pi*f1*t)
x2 = A2*np.cos(2*np.pi*f2*t)

# %%
plt.plot(x1[0:100])
plt.plot(x2[0:100])

# %%
nfft = 8000
#X1 = np.fft.fft(x1, nfft)

# %%
f1 = np.linspace(-fs/2, fs/2, len(x1))
X1 = np.fft.fft(x1)
X1shifted = np.fft.fftshift(X1)/len(x1) #normalizado sobre o numero de pontos
X1amp = np.abs(X1shifted)
plt.stem(f1,X1amp)
# Out:
# <StemContainer object of 3 artists>

# %%
f2 = np.linspace(-fs/2, fs/2, len(x2))
X2 = np.fft.fft(x2)
X2shifted = np.fft.fftshift(X2)/len(x2)
X2amp = np.abs(X2shifted)
plt.stem(f2,X2amp)
# Out:
# <StemContainer object of 3 artists>

# %%
plt.stem(f1,X1amp)
plt.stem(f2,X2amp)
plt.show()

# %%
plt.plot(audio)

# %%
A = np.fft.fft(audio)
Ashifted = np.fft.fftshift(A)/len(audio)
Aamp = np.abs(Ashifted)
plt.stem(Aamp)
# Out:
# <StemContainer object of 3 artists>

# %%
sinal = audio * x1
plt.plot(sinal)

# %%
freq = np.linspace(-fs/2, fs/2, len(sinal))
SINAL = np.fft.fft(sinal)
SINALSHIFTED = np.fft.fftshift(SINAL)/len(sinal)
SINALabs = np.abs(SINALSHIFTED)
plt.stem(freq,SINALabs)
# Out:
# <StemContainer object of 3 artists>

# %%
c = np.convolve(X1shifted, Ashifted)

# %%
plt.plot(c)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
ntaps = 100
lowcut = f1/(fs/2)
b = signal.firwin(ntaps, lowcut, pass_zero=True)
a = 1.0

#para aplicar filtro
xdem = signal.fillflirt()
